# %% [markdown]
# # Reading data from Box Drive
#
# Uses `box_utils.py` (in this repo) to auto-detect each collaborator's local Box Drive folder, so no one has to hardcode a path. Requires Box Drive installed and signed in.

# %%
from box_utils import BOX_ROOT
print("Using Box root:", BOX_ROOT)
# Out:
# Using Box root: /Users/averylee/Library/CloudStorage/Box-Box

# %%
import pandas as pd

OPD = BOX_ROOT / "OPD & TAN - Core Workspace" / "02 Oakland Police Dept (OPD)"
df = pd.read_parquet(OPD / "Data" / "Our Data" / "harmonized_calls_2021_2026.parquet")
print(df.shape)
df.head()
# Out:
# (2276366, 14)
#   agency     event_number                 address beat           call_source  \
# 0     OP  LOP210101000001       E 15TH ST&35TH AV  23X              911 CALL
# 1     OP  LOP210101000002  E 23RD ST&FRUITVALE AV  21Y  DEFAULT - PHONE INIT
# 2     OP  LOP210101000003      6929 FOOTHILL BLVD  30Y              911 CALL
# 3     OP  LOP210101000004      104TH AV&WALNUT ST  32X  DEFAULT - PHONE INIT
# 4     OP  LOP210101000005            1564 76TH AV  30X              911 CALL
#
#   priority          event_time       dispatch_time        arrival_time  \
# 0        2 2021-01-01 00:00:43 2021-01-01 11:36:56 2021-01-01 11:49:11
# 1        2 2021-01-01 00:00:51 2021-01-01 00:59:23 2021-01-01 01:00:33
# 2        2 2021-01-01 00:00:54                 NaT                 NaT
# 3        2 2021-01-01 00:01:02 2021-01-01 00:39:31 2021-01-01 00:40:58
# 4        2 2021-01-01 00:01:24                 NaT                 NaT
#
# ...
